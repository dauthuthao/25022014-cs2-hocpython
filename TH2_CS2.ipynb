# %%
#W2A1
print("Hello World!")
# Out:
# Hello World!

# %%
#W2A2
"""
a = input() #mac dinh la chuoi
b = input()
c = a + b #phep cong tren 2 chuoi ki tu
print(c) #ket qua la 1 chuoi
"""
"""
s1 = int(input())
s2 = int(input())
c = s1 + s2
print(c)
"""

"""
#nhap tung so tren 1 hang
so1, so2 =  map(int, input().split())
tong = so1 + so2 
print(tong)
"""

name = input()
print("Xin chao ban", name)
# Out:
#  Jack
# Xin chao ban Jack

# %%
#W2A3
"""
a, b = map(int,input().split('/')) #split là dấu / thay cho dấu cách
print(f'{a} + {b} = {a+b}')
"""
a, b = map(int,input().split())
#print(a, "+", b, "=", a+b)
print(f'{a} + {b} = {a+b}') #thay cho dong tren
print(f'{a} - {b} = {a-b}')
print(f'{a} * {b} = {a*b}')
print(f'{a} / {b} = {a/b}')
print(f'{a} / {b} = {a/b:.4f}') #lay so chu so sau dau phay
print(f'{a} // {b} = {a//b}') # // lay phan nguyen
# Out:
#  5 2
# 5 + 2 = 7
# 5 - 2 = 3
# 5 * 2 = 10
# 5 / 2 = 2.5
# 5 / 2 = 2.5000
# 5 // 2 = 2

# %%
#W2A4 - tinh diem TB cua 6 dau diem
a1,b1,c1,a2,b2,c2 = map(int, input().split())
tb = (a1 + b1 + c1 +(a2 + b2) * 2 + c2 * 3)/10
print(f'{tb:.1f}')
# Out:
#   8 7 9 10 10 9
# 9.1

# %%
#W2A5
a, b =  map(int,input().split())
print(f'{a**b})
# Out:
#  2 5
# 32

# %%
#W2A6
#a:97, A:32
s = input()
print(s.upper())
#print(ord('a'))  #chuyen ve ma so cua a
#print(chr(ord('a')-32)) #chuyen ma so ve ki tu
# Out:
#  z
# Z
# 97
# C

# %%
#W2A7
A = ((13**2)*3) + 5
B = 13**2*3 + 5
print(A,B)
# Out:
# 512 512

# %%
#W2A8
C = float(input())
F = (9/5)*C +32
print(f'{F:.2f}')
# Out:
#  28
# 82.40

# %%
#W2A9
x = int(input())
t = 10 + float((x*3)/10) + float(x/10)
print(f'{t:.2f}')
# Out:
#  56
# 32.40

# %%
#W2A10
s1, s2, s3 = map(str,input().split())
print("Hi", s3 + ",", s2, "and", s1)
# Out:
#  He Ha Hu
# Hi Hu, Ha and He

# %%
#W2A11
h, m = map(int,input().split())
s = h*3600 + m*60
print(s)
# Out:
#  0 1
# 60

# %%
#W2A12
n = int(input())
s = n*n*6
print(s)
# Out:
#  2
# 24

# %%
#W2A13
a, b = map(int,input().split())
kq = (a*b)%10
print(kq)
# Out:
#  999999999999999999 277182635178183
# 7

# %%
#W2A14
a, b = map(int,input().split())
if a == b:
    print('a =',a,'b =',b)
else:
    print('a =',b,'b =', a)
# Out:
#  3 2
# a = 2 b = 3

# %%
#W2A15
n = int(input())
s = 3* n * (n - 1 ) + 1
print(s)
# Out:
#  3
# 19

# %%
#W2A16
"""print('Spring')
print('Summer')
print('Autumn')
print('Winter')"""

print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
print('','','*')
print('','***')
print('*****')
# Out:
#   *
#  ***
# *****

# %%
#W2A18
print('### # #    ### ###')
print(' #  #   #   #   #')
print(' #  #    #  #   #')
print(' #  #   #   #   #')
print(' #  # #     #   #')
# Out:
# ### # #    ### ###
#  #  #   #   #   #
#  #  #    #  #   #
#  #  #   #   #   #
#  #  # #     #   #

# %%
#W2A19
print('Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday')
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
print('January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember')
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#W2A21
for i in range(1,11):
    print('Heloo, world')
# Out:
# Heloo, world
# Heloo, world
# Heloo, world
# Heloo, world
# Heloo, world
# Heloo, world
# Heloo, world
# Heloo, world
# Heloo, world
# Heloo, world
