# %%
#W3A2

# %%
#W3A3

# %%
#W3A4
import math
m,n=map(int,input().split())
s = m/n
print(s)
print(math.floor(s))
# Out:
#  5 2
# 2.5
# 2

# %%
#W3A5
import math
m,n=map(int,input().split())
s = m/n
print(s)
print(math.ceil(s))
# Out:
#  5 2
# 2.5
# 3
